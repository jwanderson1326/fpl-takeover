# %%
from fplpandas import FPLPandas
import numpy as np
import pandas as pd

# %%
fpl = FPLPandas()

# %%
teams = fpl.get_teams()
teams
# Out:
#     code  draw  form  loss            name  played  points  position  \
# id
# 1      3     0  None     0         Arsenal       0       0         0
# 2      7     0  None     0     Aston Villa       0       0         0
# 3     36     0  None     0        Brighton       0       0         0
# 4     90     0  None     0         Burnley       0       0         0
# 5      8     0  None     0         Chelsea       0       0         0
# 6     31     0  None     0  Crystal Palace       0       0         0
# 7     11     0  None     0         Everton       0       0         0
# 8     54     0  None     0          Fulham       0       0         0
# 9     13     0  None     0       Leicester       0       0         0
# 10     2     0  None     0           Leeds       0       0         0
# 11    14     0  None     0       Liverpool       0       0         0
# 12    43     0  None     0        Man City       0       0         0
# 13     1     0  None     0         Man Utd       0       0         0
# 14     4     0  None     0       Newcastle       0       0         0
# 15    49     0  None     0   Sheffield Utd       0       0         0
# 16    20     0  None     0     Southampton       0       0         0
# 17     6     0  None     0           Spurs       0       0         0
# 18    35     0  None     0       West Brom       0       0         0
# 19    21     0  None     0        West Ham       0       0         0
# 20    39     0  None     0          Wolves       0       0         0
#
#    short_name  strength team_division  unavailable  win  \
# id
# 1         ARS         4          None        False    0
# 2         AVL         3          None        False    0
# 3         BHA         3          None        False    0
# 4         BUR         2          None        False    0
# 5         CHE         4          None        False    0
# 6         CRY         3          None        False    0
# 7         EVE         3          None        False    0
# 8         FUL         2          None        False    0
# 9         LEI         4          None        False    0
# 10        LEE         3          None        False    0
# 11        LIV         5          None        False    0
# 12        MCI         5          None        False    0
# 13        MUN         4          None        False    0
# 14        NEW         3          None        False    0
# 15        SHU         3          None        False    0
# 16        SOU         3          None        False    0
# 17        TOT         4          None        False    0
# 18        WBA         2          None        False    0
# 19        WHU         3          None        False    0
# 20        WOL         3          None        False    0
#
#     strength_overall_home  strength_overall_away  strength_attack_home  \
# id
# 1                    1190                   1210                  1170
# 2                    1150                   1160                  1150
# 3                    1080                   1100                  1150
# 4                    1050                   1080                  1120
# 5                    1260                   1280                  1240
# 6                    1110                   1150                  1100
# 7                    1180                   1210                  1150
# 8                    1000                   1020                  1020
# 9                    1220                   1240                  1190
# 10                   1100                   1130                  1060
# 11                   1320                   1360                  1240
# 12                   1310                   1360                  1260
# 13                   1230                   1230                  1220
# 14                   1100                   1130                  1100
# 15                   1070                   1100                  1110
# 16                   1150                   1180                  1140
# 17                   1270                   1280                  1190
# 18                   1010                   1030                  1020
# 19                   1140                   1170                  1150
# 20                   1160                   1190                  1180
#
#     strength_attack_away  strength_defence_home  strength_defence_away  \
# id
# 1                   1210                   1190                   1200
# 2                   1150                   1180                   1210
# 3                   1180                   1090                   1100
# 4                   1190                   1010                   1030
# 5                   1280                   1270                   1310
# 6                   1150                   1020                   1050
# 7                   1170                   1210                   1250
# 8                   1030                   1020                   1020
# 9                   1190                   1200                   1180
# 10                  1110                   1130                   1160
# 11                  1320                   1330                   1350
# 12                  1320                   1330                   1350
# 13                  1230                   1250                   1260
# 14                  1120                   1010                   1060
# 15                  1130                   1010                   1050
# 16                  1200                   1110                   1160
# 17                  1240                   1280                   1320
# 18                  1020                   1000                   1010
# 19                  1160                   1170                   1180
# 20                  1220                   1100                   1170
#
#     pulse_id
# id
# 1          1
# 2          2
# 3        131
# 4         43
# 5          4
# 6          6
# 7          7
# 8         34
# 9         26
# 10         9
# 11        10
# 12        11
# 13        12
# 14        23
# 15        18
# 16        20
# 17        21
# 18        36
# 19        25
# 20        38

# %%
#player_summary, player_hist, player_fixtures, player_future = fpl.get_players()

# %%
player_dfs = fpl.get_players()

# %%
fixtures = fpl.get_fixtures()

# %%
#Clean the Player Summary Table
player_summary = player_dfs[0]
convert_dict = {'value_season': float} 
player_summary = player_summary.astype(convert_dict)
player_summary['team'] = player_summary.team_code.map(teams.set_index('code').name)

# %%
#Clean the Player Fixtures Table
player_fixtures = player_dfs[2]
convert_dict_fixture = {
    'element': int
}

player_lookup = player_summary[['web_name', 'element_type', 'team', 'minutes']]
player_fixtures = player_fixtures.astype(convert_dict_fixture)

player_fixtures = pd.merge(player_fixtures, player_lookup, left_on='element', right_on='id', how='left')

# %%
player_fixtures
# Out:
#        element  opponent_team  total_points was_home          kickoff_time  \
# 0            1            8.0           0.0    False  2020-09-12T11:30:00Z
# 1            1           19.0           0.0     True  2020-09-19T19:00:00Z
# 2            1           11.0           0.0    False  2020-09-28T19:00:00Z
# 3            1           15.0           0.0     True  2020-10-04T13:00:00Z
# 4            1           12.0           0.0    False  2020-10-17T16:30:00Z
# ...        ...            ...           ...      ...                   ...
# 11031      617           18.0           0.0     True  2021-01-16T12:30:00Z
# 11032      626            7.0           1.0     True  2021-01-12T20:15:00Z
# 11033      626           18.0           1.0     True  2021-01-16T12:30:00Z
# 11034      629            7.0           0.0     True  2021-01-12T20:15:00Z
# 11035      629           18.0           0.0     True  2021-01-16T12:30:00Z
#
#        team_h_score  team_a_score  round  minutes_x  goals_scored  ...  \
# 0               0.0           3.0    1.0        0.0           0.0  ...
# 1               2.0           1.0    2.0        0.0           0.0  ...
# 2               3.0           1.0    3.0        0.0           0.0  ...
# 3               2.0           1.0    4.0        0.0           0.0  ...
# 4               1.0           0.0    5.0        0.0           0.0  ...
# ...             ...           ...    ...        ...           ...  ...
# 11031           2.0           3.0   19.0        0.0           0.0  ...
# 11032           1.0           2.0   18.0       12.0           0.0  ...
# 11033           2.0           3.0   19.0       11.0           0.0  ...
# 11034           1.0           2.0   18.0        0.0           0.0  ...
# 11035           2.0           3.0   19.0        0.0           0.0  ...
#
#        ict_index  value  transfers_balance  selected  transfers_in  \
# 0            0.0   70.0                0.0   76656.0           0.0
# 1            0.0   69.0           -16828.0   68335.0         995.0
# 2            0.0   69.0           -11451.0   59793.0         675.0
# 3            0.0   68.0            -5324.0   56403.0         647.0
# 4            0.0   68.0            -4224.0   53689.0         616.0
# ...          ...    ...                ...       ...           ...
# 11031        0.0   40.0             4960.0   20399.0        6620.0
# 11032        0.0   60.0             1407.0    2787.0        1641.0
# 11033        0.2   60.0              503.0    1989.0        1199.0
# 11034        0.0   40.0                0.0       0.0           0.0
# 11035        0.0   40.0              247.0     681.0         304.0
#
#        transfers_out     web_name  element_type     team  minutes_y
# 0                0.0         Özil             3  Arsenal          0
# 1            17823.0         Özil             3  Arsenal          0
# 2            12126.0         Özil             3  Arsenal          0
# 3             5971.0         Özil             3  Arsenal          0
# 4             4840.0         Özil             3  Arsenal          0
# ...              ...          ...           ...      ...        ...
# 11031         1660.0  Söndergaard             1   Wolves          0
# 11032          234.0      Cutrone             4   Wolves         23
# 11033          696.0      Cutrone             4   Wolves         23
# 11034            0.0      Lonwijk             2   Wolves          0
# 11035           57.0      Lonwijk             2   Wolves          0
#
# [11036 rows x 34 columns]
